# %% [markdown]
# # Importing the Dependecies

# %%
pip install yfinance pandas numpy requests fredapi tqdm finnhub-python sec-api
# Out:
# Requirement already satisfied: yfinance in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (0.2.55)
# Requirement already satisfied: pandas in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: numpy in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: requests in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: fredapi in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (0.5.2)
# Requirement already satisfied: tqdm in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (4.66.2)
# Requirement already satisfied: finnhub-python in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (2.4.23)
# Requirement already satisfied: sec-api in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (1.0.32)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (from yfinance) (2023.4)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: peewee>=3.16.2 in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (from requests) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (from requests) (2022.12.7)
# Requirement already satisfied: soupsieve>1.2 in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: six>=1.5 in /Users/abduljalaalabubakar/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Axya Quant Platform - Data Pipeline v4.0 (TwelveData Optimized)
import os
import pandas as pd
import requests
import time
import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
from fredapi import Fred
import logging
import math

# --- Configuration ---
API_KEYS = {
    'twelvedata': '',
    'fred': ''
}

DATE_RANGE = {
    'start': '2022-01-01',
    'end': datetime.datetime.today().strftime('%Y-%m-%d')
}

DATA_PATH = os.path.abspath('./data')
os.makedirs(DATA_PATH, exist_ok=True)

# Configure logging
logging.basicConfig(
    filename=os.path.join(DATA_PATH, 'pipeline.log'),
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filemode='w'
)
logger = logging.getLogger()
logger.addHandler(logging.StreamHandler())

# --- Global Credit Tracker ---
class APICreditManager:
    def __init__(self):
        self.credits_used = 0
        self.max_credits = 800  # TwelveData daily limit
        self.lock = False
        
    def increment(self, count=1):
        if not self.lock:
            self.credits_used += count
            if self.credits_used >= self.max_credits * 0.95:  # 95% safety cutoff
                logger.critical(f"API limit reached at {self.credits_used}/800 credits")
                self.lock = True
                raise SystemExit("API credit limit exceeded")
                
credit_manager = APICreditManager()

# --- Ticker Management ---
def fetch_tickers_with_retry(url: str) -> list:
    """Fetch tickers with enhanced validation"""
    headers = {'User-Agent': 'Axya Quant Platform (research@axya.com)'}
    for attempt in range(3):
        try:
            response = requests.get(url, headers=headers, timeout=15)
            response.raise_for_status()
            return [
                t.strip() for t in response.text.splitlines()
                if t.strip() and 2 <= len(t.strip()) <= 5 and t.strip().isalpha()
            ]
        except Exception as e:
            logger.warning(f"Attempt {attempt+1} failed: {str(e)}")
            time.sleep(2 ** attempt)
    return []

def get_validated_tickers() -> list:
    """Get 500 validated tickers from major exchanges"""
    sources = {
        'nasdaq': 'https://raw.githubusercontent.com/rreichel3/US-Stock-Symbols/main/nasdaq/nasdaq_tickers.txt',
        'nyse': 'https://raw.githubusercontent.com/rreichel3/US-Stock-Symbols/main/nyse/nyse_tickers.txt'
    }
    
    tickers = []
    with ThreadPoolExecutor(max_workers=2) as executor:
        futures = {executor.submit(fetch_tickers_with_retry, url): name for name, url in sources.items()}
        for future in as_completed(futures):
            tickers.extend(future.result())
    
    valid_tickers = sorted(list(set(tickers)))[:500]  # Strict 500 ticker limit
    logger.info(f"Selected {len(valid_tickers)} tickers")
    return valid_tickers

# --- Optimized OHLCV Pipeline ---
class OHLCVDownloader:
    def __init__(self):
        self.base_url = "https://api.twelvedata.com/time_series"
        self.params = {
            'apikey': API_KEYS['twelvedata'],
            'interval': '1day',
            'outputsize': '5000',
            'timezone': 'America/New_York'
        }
        self.delay = 15  # 15s delay for 4 RPM per worker (8 RPM total)
        self.max_retries = 2  # Reduced retries to conserve credits
        self.last_request = 0
        self.workers = 2  # Maintain 8 RPM limit (2 workers × 4 RPM = 8 RPM)

    def fetch_ohlcv(self, ticker: str) -> pd.DataFrame:
        """Fetch data with credit tracking"""
        params = self.params.copy()
        params.update({
            'symbol': ticker,
            'start_date': DATE_RANGE['start'],
            'end_date': DATE_RANGE['end']
        })
        
        for attempt in range(self.max_retries + 1):  # 0-based count
            try:
                # Rate limit enforcement
                elapsed = time.time() - self.last_request
                if elapsed < self.delay:
                    sleep_time = self.delay - elapsed
                    time.sleep(sleep_time)
                
                response = requests.get(self.base_url, params=params, timeout=20)
                self.last_request = time.time()
                credit_manager.increment()
                
                # Handle rate limits
                if response.status_code == 429:
                    retry_after = int(response.headers.get('Retry-After', 60))
                    remaining = int(response.headers.get('X-Ratelimit-Requests-Remaining', 800))
                    logger.warning(f"Rate limited. Retry after {retry_after}s | Remaining: {remaining}")
                    time.sleep(retry_after + 5)
                    continue
                    
                response.raise_for_status()
                data = response.json()
                
                if data.get('status') == 'ok' and 'values' in data:
                    df = pd.DataFrame(data['values'])
                    df = df.rename(columns={
                        'datetime': 'date',
                        'open': 'open',
                        'high': 'high',
                        'low': 'low',
                        'close': 'close',
                        'volume': 'volume'
                    })
                    df['ticker'] = ticker
                    df['date'] = pd.to_datetime(df['date']).dt.date
                    return df[['date', 'open', 'high', 'low', 'close', 'volume', 'ticker']]
                
                logger.warning(f"No data for {ticker}: {data.get('message', 'Unknown error')}")
                return pd.DataFrame()
                
            except Exception as e:
                if attempt < self.max_retries:
                    logger.warning(f"Attempt {attempt+1} failed for {ticker}: {str(e)}")
                    time.sleep(math.pow(2, attempt))
                else:
                    logger.error(f"Final failure for {ticker}")
                    return pd.DataFrame()

    def run(self, tickers: list):
        """Execute with credit-aware parallel processing"""
        results = []
        failed_tickers = []
        
        with ThreadPoolExecutor(max_workers=self.workers) as executor:
            futures = {executor.submit(self.fetch_ohlcv, t): t for t in tickers}
            
            with tqdm(total=len(tickers), desc="Downloading OHLCV", unit="ticker") as pbar:
                for future in as_completed(futures):
                    ticker = futures[future]
                    result = future.result()
                    if not result.empty:
                        results.append(result)
                        logger.info(f"Success: {ticker} | Credits: {credit_manager.credits_used}/800")
                    else:
                        failed_tickers.append(ticker)
                        logger.warning(f"Failed: {ticker}")
                    pbar.update(1)
        
        if results:
            final_df = pd.concat(results)
            start_date = pd.to_datetime(DATE_RANGE['start']).date()
            end_date = pd.to_datetime(DATE_RANGE['end']).date()
            
            final_df = final_df[
                (final_df['date'] >= start_date) &
                (final_df['date'] <= end_date)
            ]
            
            final_df.to_parquet(os.path.join(DATA_PATH, 'ohlcv.parquet'))
            logger.info(f"Saved {len(final_df)} records | Failed: {len(failed_tickers)}")
            
            if failed_tickers:
                with open(os.path.join(DATA_PATH, 'failed_tickers.txt'), 'w') as f:
                    f.write('\n'.join(failed_tickers))
        return pd.concat(results) if results else pd.DataFrame()

# --- Macro Data Pipeline ---
def fetch_macro_data():
    """Fetch FRED data with error handling"""
    try:
        fred = Fred(api_key=API_KEYS['fred'])
        series = {
            'VIXCLS': 'vix',
            'T10Y2Y': 'yield_curve',
            'FEDFUNDS': 'fed_rate'
        }
        
        macro_df = pd.DataFrame()
        for series_id, col_name in series.items():
            try:
                data = fred.get_series(series_id, observation_start=DATE_RANGE['start'])
                temp_df = pd.DataFrame({'date': data.index, col_name: data.values})
                macro_df = temp_df if macro_df.empty else macro_df.merge(temp_df, on='date', how='outer')
            except Exception as e:
                logger.error(f"FRED {series_id} failed: {str(e)}")
        
        if not macro_df.empty:
            macro_df['date'] = pd.to_datetime(macro_df['date']).dt.date
            start_date = pd.to_datetime(DATE_RANGE['start']).date()
            end_date = pd.to_datetime(DATE_RANGE['end']).date()
            
            macro_df = macro_df[
                (macro_df['date'] >= start_date) &
                (macro_df['date'] <= end_date)
            ].sort_values('date').ffill()
            
            macro_df.to_parquet(os.path.join(DATA_PATH, 'macro_data.parquet'))
            logger.info(f"Saved {len(macro_df)} macro records")
        return macro_df
    except Exception as e:
        logger.error(f"Macro data failed: {str(e)}")
    return pd.DataFrame()

# --- Main Execution ---
if __name__ == "__main__":
    logger.info("Starting Axya Data Pipeline v4.0")
    
    try:
        # Step 1: Get Tickers
        tickers = get_validated_tickers()
        logger.info(f"Processing {len(tickers)} tickers")
        
        # Step 2: Download OHLCV
        ohlcv_data = OHLCVDownloader().run(tickers)
        
        # Step 3: Macro Data
        macro_data = fetch_macro_data()
        
        # Final Report
        logger.info("\n=== Pipeline Report ===")
        logger.info(f"OHLCV Records: {len(ohlcv_data) if not ohlcv_data.empty else 0}")
        logger.info(f"Macro Data Points: {len(macro_data) if not macro_data.empty else 0}")
        logger.info(f"API Credits Used: {credit_manager.credits_used}/800")
        logger.info(f"Data saved to: {DATA_PATH}")
        
    except Exception as e:
        logger.critical(f"Pipeline failed: {str(e)}")
        raise
# Out:
# Starting Axya Data Pipeline v4.0
# Selected 500 tickers
# Processing 500 tickers
# Downloading OHLCV:   0%|                            | 0/500 [00:00<?, ?ticker/s]Success: AA | Credits: 1/800
# Downloading OHLCV:   0%|                    | 1/500 [00:00<05:07,  1.62ticker/s]Success: AACB | Credits: 2/800
# Downloading OHLCV:   0%|                    | 2/500 [00:01<04:31,  1.84ticker/s]Success: AACBR | Credits: 3/800
# Downloading OHLCV:   1%|                  | 3/500 [00:16<1:00:40,  7.33s/ticker]Success: AACBU | Credits: 4/800
# Downloading OHLCV:   1%|▏                   | 4/500 [00:17<38:31,  4.66s/ticker]Success: AACG | Credits: 5/800
# Downloading OHLCV:   1%|▏                 | 5/500 [00:32<1:09:40,  8.45s/ticker]Success: AACT | Credits: 6/800
# Downloading OHLCV:   1%|▏                   | 6/500 [00:32<47:02,  5.71s/ticker]Success: AAL | Credits: 7/800
# Downloading OHLCV:   1%|▎                 | 7/500 [00:48<1:13:40,  8.97s/ticker]Success: AAM | Credits: 8/800
# Downloading OHLCV:   2%|▎                   | 8/500 [00:48<50:48,  6.20s/ticker]Success: AAMI | Credits: 9/800
# Downloading OHLCV:   2%|▎                 | 9/500 [01:04<1:14:34,  9.11s/ticker]Success: AAME | Credits: 10/800
# Downloading OHLCV:   2%|▍                  | 10/500 [01:04<52:10,  6.39s/ticker]Success: AAOI | Credits: 11/800
# Downloading OHLCV:   2%|▎                | 11/500 [01:19<1:14:37,  9.16s/ticker]Success: AAON | Credits: 12/800
# Downloading OHLCV:   2%|▍                  | 12/500 [01:20<52:28,  6.45s/ticker]Success: AAP | Credits: 13/800
# Downloading OHLCV:   3%|▍                | 13/500 [01:35<1:14:35,  9.19s/ticker]Success: AAPG | Credits: 14/800
# Downloading OHLCV:   3%|▌                  | 14/500 [01:36<53:01,  6.55s/ticker]Success: AAPL | Credits: 15/800
# Downloading OHLCV:   3%|▌                | 15/500 [01:51<1:14:17,  9.19s/ticker]Success: AARD | Credits: 16/800
# Downloading OHLCV:   3%|▌                  | 16/500 [01:52<53:56,  6.69s/ticker]Success: AAT | Credits: 17/800
# Downloading OHLCV:   3%|▌                | 17/500 [02:07<1:13:41,  9.15s/ticker]Success: AB | Credits: 18/800
# Downloading OHLCV:   4%|▋                  | 18/500 [02:08<54:18,  6.76s/ticker]Success: ABAT | Credits: 19/800
# Downloading OHLCV:   4%|▋                | 19/500 [02:22<1:12:22,  9.03s/ticker]Success: ABBV | Credits: 20/800
# Downloading OHLCV:   4%|▊                  | 20/500 [02:23<53:36,  6.70s/ticker]Success: ABCB | Credits: 21/800
# Downloading OHLCV:   4%|▋                | 21/500 [02:38<1:11:44,  8.99s/ticker]Success: ABCL | Credits: 22/800
# Downloading OHLCV:   4%|▊                  | 22/500 [02:39<53:20,  6.70s/ticker]Success: ABEO | Credits: 23/800
# Downloading OHLCV:   5%|▊                | 23/500 [02:53<1:11:28,  8.99s/ticker]Success: ABEV | Credits: 24/800
# Downloading OHLCV:   5%|▉                  | 24/500 [02:55<52:47,  6.65s/ticker]Success: ABG | Credits: 25/800
# Downloading OHLCV:   5%|▊                | 25/500 [03:09<1:11:21,  9.01s/ticker]Success: ABL | Credits: 26/800
# Downloading OHLCV:   5%|▉                  | 26/500 [03:11<53:40,  6.79s/ticker]Success: ABLLL | Credits: 27/800
# Downloading OHLCV:   5%|▉                | 27/500 [03:25<1:10:32,  8.95s/ticker]Success: ABLLW | Credits: 28/800
# Downloading OHLCV:   6%|█                  | 28/500 [03:27<53:39,  6.82s/ticker]Success: ABLV | Credits: 29/800
# Downloading OHLCV:   6%|▉                | 29/500 [03:40<1:09:57,  8.91s/ticker]Success: ABM | Credits: 30/800
# Downloading OHLCV:   6%|█▏                 | 30/500 [03:42<53:15,  6.80s/ticker]Success: ABNB | Credits: 31/800
# Downloading OHLCV:   6%|█                | 31/500 [03:56<1:09:24,  8.88s/ticker]Success: ABOS | Credits: 32/800
# Downloading OHLCV:   6%|█▏                 | 32/500 [03:58<53:26,  6.85s/ticker]Success: ABP | Credits: 33/800
# Downloading OHLCV:   7%|█                | 33/500 [04:11<1:08:39,  8.82s/ticker]Success: ABR | Credits: 34/800
# Downloading OHLCV:   7%|█▎                 | 34/500 [04:14<54:08,  6.97s/ticker]Success: ABSI | Credits: 35/800
# Downloading OHLCV:   7%|█▏               | 35/500 [04:28<1:09:01,  8.91s/ticker]Success: ABT | Credits: 36/800
# Downloading OHLCV:   7%|█▎                 | 36/500 [04:30<53:22,  6.90s/ticker]Success: ABTS | Credits: 37/800
# Downloading OHLCV:   7%|█▎               | 37/500 [04:43<1:08:36,  8.89s/ticker]Success: ABUS | Credits: 38/800
# Downloading OHLCV:   8%|█▍                 | 38/500 [04:45<52:28,  6.82s/ticker]Success: ABVC | Credits: 39/800
# Downloading OHLCV:   8%|█▎               | 39/500 [04:59<1:07:51,  8.83s/ticker]Success: ABVE | Credits: 40/800
# Downloading OHLCV:   8%|█▌                 | 40/500 [05:01<52:13,  6.81s/ticker]Success: ABVEW | Credits: 41/800
# Downloading OHLCV:   8%|█▍               | 41/500 [05:15<1:08:10,  8.91s/ticker]Success: ABVX | Credits: 42/800
# Downloading OHLCV:   8%|█▌                 | 42/500 [05:17<51:50,  6.79s/ticker]Success: AC | Credits: 43/800
# Downloading OHLCV:   9%|█▍               | 43/500 [05:31<1:08:05,  8.94s/ticker]Success: ACA | Credits: 44/800
# Downloading OHLCV:   9%|█▋                 | 44/500 [05:34<54:54,  7.23s/ticker]Success: ACAD | Credits: 45/800
# Downloading OHLCV:   9%|█▌               | 45/500 [05:47<1:07:34,  8.91s/ticker]Success: ACB | Credits: 46/800
# Downloading OHLCV:   9%|█▋                 | 46/500 [05:52<58:29,  7.73s/ticker]Success: ACCO | Credits: 47/800
# Downloading OHLCV:   9%|█▌               | 47/500 [06:02<1:05:20,  8.65s/ticker]Success: ACDC | Credits: 48/800
# Downloading OHLCV:  10%|█▊                 | 48/500 [06:07<56:50,  7.54s/ticker]Success: ACEL | Credits: 49/800
# Downloading OHLCV:  10%|█▋               | 49/500 [06:18<1:04:07,  8.53s/ticker]Success: ACET | Credits: 50/800
# Downloading OHLCV:  10%|█▉                 | 50/500 [06:23<55:53,  7.45s/ticker]Success: ACGL | Credits: 51/800
# Downloading OHLCV:  10%|█▋               | 51/500 [06:34<1:03:10,  8.44s/ticker]Success: ACGLN | Credits: 52/800
# Downloading OHLCV:  10%|█▉                 | 52/500 [06:39<56:00,  7.50s/ticker]Success: ACGLO | Credits: 53/800
# Downloading OHLCV:  11%|█▊               | 53/500 [06:50<1:03:21,  8.50s/ticker]Success: ACHC | Credits: 54/800
# Downloading OHLCV:  11%|██                 | 54/500 [06:55<54:39,  7.35s/ticker]Success: ACHR | Credits: 55/800
# Downloading OHLCV:  11%|█▊               | 55/500 [07:06<1:02:24,  8.41s/ticker]Success: ACHV | Credits: 56/800
# Downloading OHLCV:  11%|██▏                | 56/500 [07:10<54:18,  7.34s/ticker]Success: ACI | Credits: 57/800
# Downloading OHLCV:  11%|█▉               | 57/500 [07:21<1:02:01,  8.40s/ticker]Success: ACIC | Credits: 58/800
# Downloading OHLCV:  12%|██▏                | 58/500 [07:26<54:03,  7.34s/ticker]Success: ACIU | Credits: 59/800
# Downloading OHLCV:  12%|██               | 59/500 [07:37<1:01:20,  8.34s/ticker]Success: ACIW | Credits: 60/800
# Downloading OHLCV:  12%|██▎                | 60/500 [07:42<54:35,  7.44s/ticker]Success: ACLS | Credits: 61/800
# Downloading OHLCV:  12%|██               | 61/500 [07:53<1:01:03,  8.35s/ticker]Success: ACLX | Credits: 62/800
# Downloading OHLCV:  12%|██▎                | 62/500 [07:58<55:00,  7.53s/ticker]Success: ACM | Credits: 63/800
# Downloading OHLCV:  13%|██▍                | 63/500 [08:08<59:59,  8.24s/ticker]Success: ACMR | Credits: 64/800
# Downloading OHLCV:  13%|██▍                | 64/500 [08:14<54:43,  7.53s/ticker]Success: ACN | Credits: 65/800
# Downloading OHLCV:  13%|██▍                | 65/500 [08:24<59:40,  8.23s/ticker]Success: ACNB | Credits: 66/800
# Downloading OHLCV:  13%|██▌                | 66/500 [08:30<54:21,  7.52s/ticker]Success: ACNT | Credits: 67/800
# Downloading OHLCV:  13%|██▎              | 67/500 [08:40<1:00:12,  8.34s/ticker]Success: ACOG | Credits: 68/800
# Downloading OHLCV:  14%|██▌                | 68/500 [08:45<53:18,  7.40s/ticker]Success: ACON | Credits: 69/800
# Downloading OHLCV:  14%|██▎              | 69/500 [08:56<1:00:42,  8.45s/ticker]Success: ACONW | Credits: 70/800
# Downloading OHLCV:  14%|██▋                | 70/500 [09:01<53:13,  7.43s/ticker]Success: ACP | Credits: 71/800
# Downloading OHLCV:  14%|██▍              | 71/500 [09:12<1:00:13,  8.42s/ticker]Success: ACR | Credits: 72/800
# Downloading OHLCV:  14%|██▋                | 72/500 [09:17<52:44,  7.39s/ticker]Success: ACRE | Credits: 73/800
# Downloading OHLCV:  15%|██▍              | 73/500 [09:28<1:00:27,  8.50s/ticker]Success: ACRS | Credits: 74/800
# Downloading OHLCV:  15%|██▊                | 74/500 [09:33<51:55,  7.31s/ticker]Success: ACRV | Credits: 75/800
# Downloading OHLCV:  15%|██▊                | 75/500 [09:43<59:33,  8.41s/ticker]Success: ACT | Credits: 76/800
# Downloading OHLCV:  15%|██▉                | 76/500 [09:48<51:45,  7.33s/ticker]Success: ACTG | Credits: 77/800
# Downloading OHLCV:  15%|██▉                | 77/500 [09:59<58:50,  8.35s/ticker]Success: ACTU | Credits: 78/800
# Downloading OHLCV:  16%|██▉                | 78/500 [10:04<51:08,  7.27s/ticker]Success: ACV | Credits: 79/800
# Downloading OHLCV:  16%|███                | 79/500 [10:15<59:29,  8.48s/ticker]Success: ACVA | Credits: 80/800
# Downloading OHLCV:  16%|███                | 80/500 [10:20<51:18,  7.33s/ticker]Success: ACXP | Credits: 81/800
# Downloading OHLCV:  16%|███                | 81/500 [10:31<58:38,  8.40s/ticker]Success: ADAG | Credits: 82/800
# Downloading OHLCV:  16%|███                | 82/500 [10:36<51:35,  7.41s/ticker]Success: ADAP | Credits: 83/800
# Downloading OHLCV:  17%|███▏               | 83/500 [10:46<58:10,  8.37s/ticker]Success: ADBE | Credits: 84/800
# Downloading OHLCV:  17%|███▏               | 84/500 [10:51<50:45,  7.32s/ticker]Success: ADC | Credits: 85/800
# Downloading OHLCV:  17%|███▏               | 85/500 [11:02<57:42,  8.34s/ticker]Success: ADCT | Credits: 86/800
# Downloading OHLCV:  17%|███▎               | 86/500 [11:07<51:27,  7.46s/ticker]Success: ADD | Credits: 87/800
# Downloading OHLCV:  17%|███▎               | 87/500 [11:18<58:19,  8.47s/ticker]Success: ADEA | Credits: 88/800
# Downloading OHLCV:  18%|███▎               | 88/500 [11:23<50:19,  7.33s/ticker]Success: ADGM | Credits: 89/800
# Downloading OHLCV:  18%|███▍               | 89/500 [11:34<57:23,  8.38s/ticker]Success: ADI | Credits: 90/800
# Downloading OHLCV:  18%|███▍               | 90/500 [11:39<50:57,  7.46s/ticker]Success: ADIL | Credits: 91/800
# Downloading OHLCV:  18%|███▍               | 91/500 [11:49<56:53,  8.35s/ticker]Success: ADM | Credits: 92/800
# Downloading OHLCV:  18%|███▍               | 92/500 [11:55<50:36,  7.44s/ticker]Success: ADMA | Credits: 93/800
# Downloading OHLCV:  19%|███▌               | 93/500 [12:05<56:08,  8.28s/ticker]Success: ADN | Credits: 94/800
# Downloading OHLCV:  19%|███▌               | 94/500 [12:10<50:19,  7.44s/ticker]Success: ADNT | Credits: 95/800
# Downloading OHLCV:  19%|███▌               | 95/500 [12:21<56:35,  8.38s/ticker]Success: ADNWW | Credits: 96/800
# Downloading OHLCV:  19%|███▋               | 96/500 [12:27<51:01,  7.58s/ticker]Success: ADP | Credits: 97/800
# Downloading OHLCV:  19%|███▋               | 97/500 [12:37<55:40,  8.29s/ticker]Success: ADPT | Credits: 98/800
# Downloading OHLCV:  20%|███▋               | 98/500 [12:42<50:21,  7.52s/ticker]Success: ADSE | Credits: 99/800
# Downloading OHLCV:  20%|███▊               | 99/500 [12:52<54:58,  8.23s/ticker]Success: ADSEW | Credits: 100/800
# Downloading OHLCV:  20%|███▌              | 100/500 [12:58<50:19,  7.55s/ticker]Success: ADSK | Credits: 101/800
# Downloading OHLCV:  20%|███▋              | 101/500 [13:08<54:38,  8.22s/ticker]Success: ADT | Credits: 102/800
# Downloading OHLCV:  20%|███▋              | 102/500 [13:14<49:54,  7.52s/ticker]Success: ADTN | Credits: 103/800
# Downloading OHLCV:  21%|███▋              | 103/500 [13:24<54:06,  8.18s/ticker]Success: ADTX | Credits: 104/800
# Downloading OHLCV:  21%|███▋              | 104/500 [13:30<50:22,  7.63s/ticker]Success: ADUR | Credits: 105/800
# Downloading OHLCV:  21%|███▊              | 105/500 [13:39<53:51,  8.18s/ticker]Success: ADUS | Credits: 106/800
# Downloading OHLCV:  21%|███▊              | 106/500 [13:46<49:58,  7.61s/ticker]Success: ADV | Credits: 107/800
# Downloading OHLCV:  21%|███▊              | 107/500 [13:55<53:29,  8.17s/ticker]Success: ADVB | Credits: 108/800
# Downloading OHLCV:  22%|███▉              | 108/500 [14:02<50:01,  7.66s/ticker]Success: ADVM | Credits: 109/800
# Downloading OHLCV:  22%|███▉              | 109/500 [14:11<53:00,  8.14s/ticker]Success: ADVWW | Credits: 110/800
# Downloading OHLCV:  22%|███▉              | 110/500 [14:18<50:01,  7.70s/ticker]Success: ADX | Credits: 111/800
# Downloading OHLCV:  22%|███▉              | 111/500 [14:27<53:31,  8.26s/ticker]Success: ADXN | Credits: 112/800
# Downloading OHLCV:  22%|████              | 112/500 [14:33<48:57,  7.57s/ticker]Success: AEE | Credits: 113/800
# Downloading OHLCV:  23%|████              | 113/500 [14:43<53:06,  8.23s/ticker]Success: AEFC | Credits: 114/800
# Downloading OHLCV:  23%|████              | 114/500 [14:49<49:44,  7.73s/ticker]Success: AEG | Credits: 115/800
# Downloading OHLCV:  23%|████▏             | 115/500 [14:58<51:57,  8.10s/ticker]Success: AEHL | Credits: 116/800
# Downloading OHLCV:  23%|████▏             | 116/500 [15:05<49:15,  7.70s/ticker]Success: AEHR | Credits: 117/800
# Downloading OHLCV:  23%|████▏             | 117/500 [15:14<52:14,  8.19s/ticker]Success: AEI | Credits: 118/800
# Downloading OHLCV:  24%|████▏             | 118/500 [15:21<48:43,  7.65s/ticker]Success: AEIS | Credits: 119/800
# Downloading OHLCV:  24%|████▎             | 119/500 [15:30<51:51,  8.17s/ticker]Success: AEM | Credits: 120/800
# Downloading OHLCV:  24%|████▎             | 120/500 [15:37<48:20,  7.63s/ticker]Success: AEMD | Credits: 121/800
# Downloading OHLCV:  24%|████▎             | 121/500 [15:46<51:24,  8.14s/ticker]Success: AENT | Credits: 122/800
# Downloading OHLCV:  24%|████▍             | 122/500 [15:53<50:06,  7.95s/ticker]Success: AENTW | Credits: 123/800
# Downloading OHLCV:  25%|████▍             | 123/500 [16:02<50:58,  8.11s/ticker]Success: AEO | Credits: 124/800
# Downloading OHLCV:  25%|████▍             | 124/500 [16:09<49:12,  7.85s/ticker]Success: AEP | Credits: 125/800
# Downloading OHLCV:  25%|████▌             | 125/500 [16:18<50:13,  8.04s/ticker]Success: AER | Credits: 126/800
# Downloading OHLCV:  25%|████▌             | 126/500 [16:25<48:38,  7.80s/ticker]Success: AERT | Credits: 127/800
# Downloading OHLCV:  25%|████▌             | 127/500 [16:34<50:33,  8.13s/ticker]Success: AERTW | Credits: 128/800
# Downloading OHLCV:  26%|████▌             | 128/500 [16:41<48:15,  7.78s/ticker]Success: AES | Credits: 129/800
# Downloading OHLCV:  26%|████▋             | 129/500 [16:49<49:38,  8.03s/ticker]Success: AESI | Credits: 130/800
# Downloading OHLCV:  26%|████▋             | 130/500 [16:56<47:44,  7.74s/ticker]Success: AEVA | Credits: 131/800
# Downloading OHLCV:  26%|████▋             | 131/500 [17:05<49:17,  8.01s/ticker]Success: AEVAW | Credits: 132/800
# Downloading OHLCV:  26%|████▊             | 132/500 [17:13<48:20,  7.88s/ticker]Success: AEYE | Credits: 133/800
# Downloading OHLCV:  27%|████▊             | 133/500 [17:21<48:45,  7.97s/ticker]Success: AFB | Credits: 134/800
# Downloading OHLCV:  27%|████▊             | 134/500 [17:29<48:28,  7.95s/ticker]Success: AFBI | Credits: 135/800
# Downloading OHLCV:  27%|████▊             | 135/500 [17:37<48:08,  7.91s/ticker]Success: AFCG | Credits: 136/800
# Downloading OHLCV:  27%|████▉             | 136/500 [17:45<48:37,  8.01s/ticker]Success: AFG | Credits: 137/800
# Downloading OHLCV:  27%|████▉             | 137/500 [17:52<47:12,  7.80s/ticker]Success: AFGB | Credits: 138/800
# Downloading OHLCV:  28%|████▉             | 138/500 [18:01<48:58,  8.12s/ticker]Success: AFGC | Credits: 139/800
# Downloading OHLCV:  28%|█████             | 139/500 [18:08<47:12,  7.85s/ticker]Success: AFGD | Credits: 140/800
# Downloading OHLCV:  28%|█████             | 140/500 [18:17<49:13,  8.20s/ticker]Success: AFGE | Credits: 141/800
# Downloading OHLCV:  28%|█████             | 141/500 [18:24<46:56,  7.85s/ticker]Success: AFJK | Credits: 142/800
# Downloading OHLCV:  28%|█████             | 142/500 [18:34<50:07,  8.40s/ticker]Success: AFJKR | Credits: 143/800
# Downloading OHLCV:  29%|█████▏            | 143/500 [18:40<45:59,  7.73s/ticker]Success: AFL | Credits: 144/800
# Downloading OHLCV:  29%|█████▏            | 144/500 [18:50<49:09,  8.28s/ticker]Success: AFMD | Credits: 145/800
# Downloading OHLCV:  29%|█████▏            | 145/500 [18:56<44:49,  7.58s/ticker]Success: AFRI | Credits: 146/800
# Downloading OHLCV:  29%|█████▎            | 146/500 [19:05<48:38,  8.24s/ticker]Success: AFRIW | Credits: 147/800
# Downloading OHLCV:  29%|█████▎            | 147/500 [19:12<45:10,  7.68s/ticker]Success: AFRM | Credits: 148/800
# Downloading OHLCV:  30%|█████▎            | 148/500 [19:21<47:36,  8.12s/ticker]Success: AFYA | Credits: 149/800
# Downloading OHLCV:  30%|█████▎            | 149/500 [19:28<44:49,  7.66s/ticker]Success: AG | Credits: 150/800
# Downloading OHLCV:  30%|█████▍            | 150/500 [19:37<47:17,  8.11s/ticker]Success: AGAE | Credits: 151/800
# Downloading OHLCV:  30%|█████▍            | 151/500 [19:43<44:09,  7.59s/ticker]Success: AGCO | Credits: 152/800
# Downloading OHLCV:  30%|█████▍            | 152/500 [19:52<47:04,  8.12s/ticker]Success: AGD | Credits: 153/800
# Downloading OHLCV:  31%|█████▌            | 153/500 [20:00<45:36,  7.89s/ticker]Success: AGEN | Credits: 154/800
# Downloading OHLCV:  31%|█████▌            | 154/500 [20:08<46:07,  8.00s/ticker]Success: AGFY | Credits: 155/800
# Downloading OHLCV:  31%|█████▌            | 155/500 [20:16<45:39,  7.94s/ticker]Success: AGH | Credits: 156/800
# Downloading OHLCV:  31%|█████▌            | 156/500 [20:23<45:01,  7.85s/ticker]Success: AGI | Credits: 157/800
# Downloading OHLCV:  31%|█████▋            | 157/500 [20:32<45:51,  8.02s/ticker]Success: AGIO | Credits: 158/800
# Downloading OHLCV:  32%|█████▋            | 158/500 [20:39<44:07,  7.74s/ticker]Success: AGL | Credits: 159/800
# Downloading OHLCV:  32%|█████▋            | 159/500 [20:47<45:12,  7.95s/ticker]Success: AGM | Credits: 160/800
# Downloading OHLCV:  32%|█████▊            | 160/500 [20:55<43:56,  7.76s/ticker]Success: AGMH | Credits: 161/800
# Downloading OHLCV:  32%|█████▊            | 161/500 [21:03<45:00,  7.96s/ticker]Success: AGNC | Credits: 162/800
# Downloading OHLCV:  32%|█████▊            | 162/500 [21:11<44:17,  7.86s/ticker]Success: AGNCL | Credits: 163/800
# Downloading OHLCV:  33%|█████▊            | 163/500 [21:19<45:05,  8.03s/ticker]Success: AGNCM | Credits: 164/800
# Downloading OHLCV:  33%|█████▉            | 164/500 [21:27<44:43,  7.99s/ticker]Success: AGNCN | Credits: 165/800
# Downloading OHLCV:  33%|█████▉            | 165/500 [21:36<45:33,  8.16s/ticker]Success: AGNCO | Credits: 166/800
# Downloading OHLCV:  33%|█████▉            | 166/500 [21:43<44:46,  8.04s/ticker]Success: AGNCP | Credits: 167/800
# Downloading OHLCV:  33%|██████            | 167/500 [21:51<44:27,  8.01s/ticker]Success: AGO | Credits: 168/800
# Downloading OHLCV:  34%|██████            | 168/500 [22:00<44:33,  8.05s/ticker]Success: AGRI | Credits: 169/800
# Downloading OHLCV:  34%|██████            | 169/500 [22:07<44:10,  8.01s/ticker]Success: AGRO | Credits: 170/800
# Downloading OHLCV:  34%|██████            | 170/500 [22:15<43:45,  7.96s/ticker]Success: AGS | Credits: 171/800
# Downloading OHLCV:  34%|██████▏           | 171/500 [22:24<44:33,  8.13s/ticker]Success: AGX | Credits: 172/800
# Downloading OHLCV:  34%|██████▏           | 172/500 [22:31<42:55,  7.85s/ticker]Success: AGYS | Credits: 173/800
# Downloading OHLCV:  35%|██████▏           | 173/500 [22:40<43:53,  8.05s/ticker]Success: AHCO | Credits: 174/800
# Downloading OHLCV:  35%|██████▎           | 174/500 [22:47<42:20,  7.79s/ticker]Success: AHG | Credits: 175/800
# Downloading OHLCV:  35%|██████▎           | 175/500 [22:55<43:26,  8.02s/ticker]Success: AHH | Credits: 176/800
# Downloading OHLCV:  35%|██████▎           | 176/500 [23:03<42:30,  7.87s/ticker]Success: AHL | Credits: 177/800
# Downloading OHLCV:  35%|██████▎           | 177/500 [23:11<43:06,  8.01s/ticker]Success: AHR | Credits: 178/800
# Downloading OHLCV:  36%|██████▍           | 178/500 [23:19<42:21,  7.89s/ticker]Success: AHT | Credits: 179/800
# Downloading OHLCV:  36%|██████▍           | 179/500 [23:27<42:34,  7.96s/ticker]Success: AI | Credits: 180/800
# Downloading OHLCV:  36%|██████▍           | 180/500 [23:34<41:39,  7.81s/ticker]Success: AIFE | Credits: 181/800
# Downloading OHLCV:  36%|██████▌           | 181/500 [23:43<42:31,  8.00s/ticker]Success: AIFEU | Credits: 182/800
# Downloading OHLCV:  36%|██████▌           | 182/500 [23:50<41:28,  7.82s/ticker]Success: AIFF | Credits: 183/800
# Downloading OHLCV:  37%|██████▌           | 183/500 [23:59<42:42,  8.08s/ticker]Success: AIFU | Credits: 184/800
# Downloading OHLCV:  37%|██████▌           | 184/500 [24:06<40:32,  7.70s/ticker]Success: AIG | Credits: 185/800
# Downloading OHLCV:  37%|██████▋           | 185/500 [24:15<42:32,  8.10s/ticker]Success: AIHS | Credits: 186/800
# Downloading OHLCV:  37%|██████▋           | 186/500 [24:21<40:12,  7.68s/ticker]Success: AII | Credits: 187/800
# Downloading OHLCV:  37%|██████▋           | 187/500 [24:31<42:32,  8.16s/ticker]Success: AIMD | Credits: 188/800
# Downloading OHLCV:  38%|██████▊           | 188/500 [24:37<39:46,  7.65s/ticker]Success: AIMDW | Credits: 189/800
# Downloading OHLCV:  38%|██████▊           | 189/500 [24:47<42:32,  8.21s/ticker]Success: AIN | Credits: 190/800
# Downloading OHLCV:  38%|██████▊           | 190/500 [24:53<38:58,  7.54s/ticker]Success: AIO | Credits: 191/800
# Downloading OHLCV:  38%|██████▉           | 191/500 [25:03<43:26,  8.44s/ticker]Success: AIOT | Credits: 192/800
# Downloading OHLCV:  38%|██████▉           | 192/500 [25:08<38:32,  7.51s/ticker]Success: AIP | Credits: 193/800
# Downloading OHLCV:  39%|██████▉           | 193/500 [25:19<42:52,  8.38s/ticker]Success: AIR | Credits: 194/800
# Downloading OHLCV:  39%|██████▉           | 194/500 [25:24<37:40,  7.39s/ticker]Success: AIRE | Credits: 195/800
# Downloading OHLCV:  39%|███████           | 195/500 [25:34<42:09,  8.29s/ticker]Success: AIRG | Credits: 196/800
# Downloading OHLCV:  39%|███████           | 196/500 [25:40<38:10,  7.53s/ticker]Success: AIRJ | Credits: 197/800
# Downloading OHLCV:  39%|███████           | 197/500 [25:50<41:31,  8.22s/ticker]Success: AIRJW | Credits: 198/800
# Downloading OHLCV:  40%|███████▏          | 198/500 [25:56<38:10,  7.58s/ticker]Success: AIRS | Credits: 199/800
# Downloading OHLCV:  40%|███████▏          | 199/500 [26:06<41:39,  8.30s/ticker]Success: AIRT | Credits: 200/800
# Downloading OHLCV:  40%|███████▏          | 200/500 [26:12<38:22,  7.68s/ticker]Success: AIRTP | Credits: 201/800
# Downloading OHLCV:  40%|███████▏          | 201/500 [26:22<41:21,  8.30s/ticker]Success: AISP | Credits: 202/800
# Downloading OHLCV:  40%|███████▎          | 202/500 [26:28<37:36,  7.57s/ticker]Success: AISPW | Credits: 203/800
# Downloading OHLCV:  41%|███████▎          | 203/500 [26:38<41:05,  8.30s/ticker]Success: AIT | Credits: 204/800
# Downloading OHLCV:  41%|███████▎          | 204/500 [26:44<37:09,  7.53s/ticker]Success: AIV | Credits: 205/800
# Downloading OHLCV:  41%|███████▍          | 205/500 [26:54<40:31,  8.24s/ticker]Success: AIXI | Credits: 206/800
# Downloading OHLCV:  41%|███████▍          | 206/500 [26:59<36:38,  7.48s/ticker]Success: AIZ | Credits: 207/800
# Downloading OHLCV:  41%|███████▍          | 207/500 [27:09<40:07,  8.22s/ticker]Success: AIZN | Credits: 208/800
# Downloading OHLCV:  42%|███████▍          | 208/500 [27:15<37:12,  7.64s/ticker]Success: AJG | Credits: 209/800
# Downloading OHLCV:  42%|███████▌          | 209/500 [27:25<39:22,  8.12s/ticker]Success: AKA | Credits: 210/800
# Downloading OHLCV:  42%|███████▌          | 210/500 [27:32<37:51,  7.83s/ticker]Success: AKAM | Credits: 211/800
# Downloading OHLCV:  42%|███████▌          | 211/500 [27:40<38:46,  8.05s/ticker]Success: AKAN | Credits: 212/800
# Downloading OHLCV:  42%|███████▋          | 212/500 [27:48<37:16,  7.77s/ticker]Success: AKBA | Credits: 213/800
# Downloading OHLCV:  43%|███████▋          | 213/500 [27:56<38:05,  7.96s/ticker]No data for AKO: **symbol** AKO is not available with your plan. You may select the appropriate plan at https://twelvedata.com/pricing
# Failed: AKO
# Downloading OHLCV:  43%|███████▋          | 214/500 [28:03<36:41,  7.70s/ticker]Success: AKR | Credits: 215/800
# Downloading OHLCV:  43%|███████▋          | 215/500 [28:12<37:54,  7.98s/ticker]Success: AKRO | Credits: 216/800
# Downloading OHLCV:  43%|███████▊          | 216/500 [28:19<36:15,  7.66s/ticker]Success: AKTX | Credits: 217/800
# Downloading OHLCV:  43%|███████▊          | 217/500 [28:27<37:26,  7.94s/ticker]Success: AKYA | Credits: 218/800
# Downloading OHLCV:  44%|███████▊          | 218/500 [28:34<35:53,  7.64s/ticker]Success: AL | Credits: 219/800
# Downloading OHLCV:  44%|███████▉          | 219/500 [28:43<37:07,  7.93s/ticker]Success: ALAB | Credits: 220/800
# Downloading OHLCV:  44%|███████▉          | 220/500 [28:50<35:34,  7.62s/ticker]Success: ALAR | Credits: 221/800
# Downloading OHLCV:  44%|███████▉          | 221/500 [28:58<36:49,  7.92s/ticker]Success: ALB | Credits: 222/800
# Downloading OHLCV:  44%|███████▉          | 222/500 [29:05<35:34,  7.68s/ticker]Success: ALBT | Credits: 223/800
# Downloading OHLCV:  45%|████████          | 223/500 [29:14<36:25,  7.89s/ticker]Success: ALC | Credits: 224/800
# Downloading OHLCV:  45%|████████          | 224/500 [29:21<35:26,  7.70s/ticker]Success: ALCO | Credits: 225/800
# Downloading OHLCV:  45%|████████          | 225/500 [29:29<36:01,  7.86s/ticker]Success: ALCY | Credits: 226/800
# Downloading OHLCV:  45%|████████▏         | 226/500 [29:36<35:04,  7.68s/ticker]Success: ALDF | Credits: 227/800
# Downloading OHLCV:  45%|████████▏         | 227/500 [29:46<36:48,  8.09s/ticker]Success: ALDFU | Credits: 228/800
# Downloading OHLCV:  46%|████████▏         | 228/500 [29:52<34:58,  7.71s/ticker]Success: ALDFW | Credits: 229/800
# Downloading OHLCV:  46%|████████▏         | 229/500 [30:01<36:37,  8.11s/ticker]Success: ALDX | Credits: 230/800
# Downloading OHLCV:  46%|████████▎         | 230/500 [30:08<34:35,  7.69s/ticker]Success: ALE | Credits: 231/800
# Downloading OHLCV:  46%|████████▎         | 231/500 [30:17<36:05,  8.05s/ticker]Success: ALEC | Credits: 232/800
# Downloading OHLCV:  46%|████████▎         | 232/500 [30:24<34:18,  7.68s/ticker]Success: ALEX | Credits: 233/800
# Downloading OHLCV:  47%|████████▍         | 233/500 [30:33<35:32,  7.99s/ticker]Success: ALF | Credits: 234/800
# Downloading OHLCV:  47%|████████▍         | 234/500 [30:40<34:36,  7.81s/ticker]Success: ALFUW | Credits: 235/800
# Downloading OHLCV:  47%|████████▍         | 235/500 [30:48<35:24,  8.02s/ticker]Success: ALG | Credits: 236/800
# Downloading OHLCV:  47%|████████▍         | 236/500 [30:56<34:18,  7.80s/ticker]Success: ALGM | Credits: 237/800
# Downloading OHLCV:  47%|████████▌         | 237/500 [31:04<34:43,  7.92s/ticker]Success: ALGN | Credits: 238/800
# Downloading OHLCV:  48%|████████▌         | 238/500 [31:11<34:05,  7.81s/ticker]Success: ALGS | Credits: 239/800
# Downloading OHLCV:  48%|████████▌         | 239/500 [31:19<34:11,  7.86s/ticker]Success: ALGT | Credits: 240/800
# Downloading OHLCV:  48%|████████▋         | 240/500 [31:27<33:52,  7.82s/ticker]Success: ALHC | Credits: 241/800
# Downloading OHLCV:  48%|████████▋         | 241/500 [31:36<34:36,  8.02s/ticker]Success: ALIT | Credits: 242/800
# Downloading OHLCV:  48%|████████▋         | 242/500 [31:43<33:10,  7.72s/ticker]Success: ALK | Credits: 243/800
# Downloading OHLCV:  49%|████████▋         | 243/500 [31:51<34:23,  8.03s/ticker]Success: ALKS | Credits: 244/800
# Downloading OHLCV:  49%|████████▊         | 244/500 [31:59<33:23,  7.83s/ticker]Success: ALKT | Credits: 245/800
# Downloading OHLCV:  49%|████████▊         | 245/500 [32:07<33:59,  8.00s/ticker]Success: ALL | Credits: 246/800
# Downloading OHLCV:  49%|████████▊         | 246/500 [32:15<33:01,  7.80s/ticker]Success: ALLE | Credits: 247/800
# Downloading OHLCV:  49%|████████▉         | 247/500 [32:23<33:26,  7.93s/ticker]Success: ALLK | Credits: 248/800
# Downloading OHLCV:  50%|████████▉         | 248/500 [32:30<32:29,  7.73s/ticker]Success: ALLO | Credits: 249/800
# Downloading OHLCV:  50%|████████▉         | 249/500 [32:39<33:17,  7.96s/ticker]Success: ALLR | Credits: 250/800
# Downloading OHLCV:  50%|█████████         | 250/500 [32:46<32:42,  7.85s/ticker]Success: ALLT | Credits: 251/800
# Downloading OHLCV:  50%|█████████         | 251/500 [32:54<32:55,  7.93s/ticker]Success: ALLY | Credits: 252/800
# Downloading OHLCV:  50%|█████████         | 252/500 [33:02<32:20,  7.82s/ticker]Success: ALMS | Credits: 253/800
# Downloading OHLCV:  51%|█████████         | 253/500 [33:10<32:18,  7.85s/ticker]Success: ALMU | Credits: 254/800
# Downloading OHLCV:  51%|█████████▏        | 254/500 [33:17<31:55,  7.79s/ticker]Success: ALNT | Credits: 255/800
# Downloading OHLCV:  51%|█████████▏        | 255/500 [33:25<32:10,  7.88s/ticker]Success: ALNY | Credits: 256/800
# Downloading OHLCV:  51%|█████████▏        | 256/500 [33:34<33:03,  8.13s/ticker]Success: ALOT | Credits: 257/800
# Downloading OHLCV:  51%|█████████▎        | 257/500 [33:41<31:24,  7.76s/ticker]Success: ALRM | Credits: 258/800
# Downloading OHLCV:  52%|█████████▎        | 258/500 [33:50<33:01,  8.19s/ticker]Success: ALRS | Credits: 259/800
# Downloading OHLCV:  52%|█████████▎        | 259/500 [33:57<30:47,  7.67s/ticker]Success: ALSN | Credits: 260/800
# Downloading OHLCV:  52%|█████████▎        | 260/500 [34:06<32:35,  8.15s/ticker]Success: ALT | Credits: 261/800
# Downloading OHLCV:  52%|█████████▍        | 261/500 [34:12<30:27,  7.65s/ticker]Success: ALTG | Credits: 262/800
# Downloading OHLCV:  52%|█████████▍        | 262/500 [34:22<32:55,  8.30s/ticker]Success: ALTI | Credits: 263/800
# Downloading OHLCV:  53%|█████████▍        | 263/500 [34:29<30:38,  7.76s/ticker]Success: ALTO | Credits: 264/800
# Downloading OHLCV:  53%|█████████▌        | 264/500 [34:38<32:02,  8.15s/ticker]Success: ALTS | Credits: 265/800
# Downloading OHLCV:  53%|█████████▌        | 265/500 [34:45<30:53,  7.89s/ticker]Success: ALUR | Credits: 266/800
# Downloading OHLCV:  53%|█████████▌        | 266/500 [34:53<31:14,  8.01s/ticker]Success: ALV | Credits: 267/800
# Downloading OHLCV:  53%|█████████▌        | 267/500 [35:01<30:48,  7.93s/ticker]Success: ALVO | Credits: 268/800
# Downloading OHLCV:  54%|█████████▋        | 268/500 [35:09<30:28,  7.88s/ticker]Success: ALVOW | Credits: 269/800
# Downloading OHLCV:  54%|█████████▋        | 269/500 [35:17<31:03,  8.07s/ticker]Success: ALX | Credits: 270/800
# Downloading OHLCV:  54%|█████████▋        | 270/500 [35:24<29:42,  7.75s/ticker]Success: ALXO | Credits: 271/800
# Downloading OHLCV:  54%|█████████▊        | 271/500 [35:33<30:41,  8.04s/ticker]Success: ALZN | Credits: 272/800
# Downloading OHLCV:  54%|█████████▊        | 272/500 [35:40<29:11,  7.68s/ticker]Success: AM | Credits: 273/800
# Downloading OHLCV:  55%|█████████▊        | 273/500 [35:49<30:20,  8.02s/ticker]Success: AMAL | Credits: 274/800
# Downloading OHLCV:  55%|█████████▊        | 274/500 [35:56<28:46,  7.64s/ticker]Success: AMAT | Credits: 275/800
# Downloading OHLCV:  55%|█████████▉        | 275/500 [36:04<29:52,  7.97s/ticker]Success: AMBA | Credits: 276/800
# Downloading OHLCV:  55%|█████████▉        | 276/500 [36:12<29:04,  7.79s/ticker]Success: AMBC | Credits: 277/800
# Downloading OHLCV:  55%|█████████▉        | 277/500 [36:20<29:34,  7.96s/ticker]Success: AMBP | Credits: 278/800
# Downloading OHLCV:  56%|██████████        | 278/500 [36:27<28:49,  7.79s/ticker]Success: AMBR | Credits: 279/800
# Downloading OHLCV:  56%|██████████        | 279/500 [36:36<29:42,  8.06s/ticker]Success: AMC | Credits: 280/800
# Downloading OHLCV:  56%|██████████        | 280/500 [36:43<28:10,  7.69s/ticker]Success: AMCR | Credits: 281/800
# Downloading OHLCV:  56%|██████████        | 281/500 [36:52<29:24,  8.06s/ticker]Success: AMCX | Credits: 282/800
# Downloading OHLCV:  56%|██████████▏       | 282/500 [36:58<27:42,  7.62s/ticker]Success: AMD | Credits: 283/800
# Downloading OHLCV:  57%|██████████▏       | 283/500 [37:08<29:33,  8.17s/ticker]Success: AME | Credits: 284/800
# Downloading OHLCV:  57%|██████████▏       | 284/500 [37:14<27:22,  7.60s/ticker]Success: AMED | Credits: 285/800
# Downloading OHLCV:  57%|██████████▎       | 285/500 [37:24<29:14,  8.16s/ticker]Success: AMG | Credits: 286/800
# Downloading OHLCV:  57%|██████████▎       | 286/500 [37:30<27:05,  7.59s/ticker]Success: AMGN | Credits: 287/800
# Downloading OHLCV:  57%|██████████▎       | 287/500 [37:39<28:56,  8.15s/ticker]Success: AMH | Credits: 288/800
# Downloading OHLCV:  58%|██████████▎       | 288/500 [37:45<26:36,  7.53s/ticker]Success: AMIX | Credits: 289/800
# Downloading OHLCV:  58%|██████████▍       | 289/500 [37:55<28:52,  8.21s/ticker]Success: AMKR | Credits: 290/800
# Downloading OHLCV:  58%|██████████▍       | 290/500 [38:01<26:06,  7.46s/ticker]Success: AMLX | Credits: 291/800
# Downloading OHLCV:  58%|██████████▍       | 291/500 [38:11<29:02,  8.34s/ticker]Success: AMN | Credits: 292/800
# Downloading OHLCV:  58%|██████████▌       | 292/500 [38:16<25:36,  7.39s/ticker]Success: AMOD | Credits: 293/800
# Downloading OHLCV:  59%|██████████▌       | 293/500 [38:27<28:40,  8.31s/ticker]Success: AMODW | Credits: 294/800
# Downloading OHLCV:  59%|██████████▌       | 294/500 [38:32<25:34,  7.45s/ticker]Success: AMP | Credits: 295/800
# Downloading OHLCV:  59%|██████████▌       | 295/500 [38:43<28:24,  8.31s/ticker]Success: AMPG | Credits: 296/800
# Downloading OHLCV:  59%|██████████▋       | 296/500 [38:48<25:38,  7.54s/ticker]Success: AMPGW | Credits: 297/800
# Downloading OHLCV:  59%|██████████▋       | 297/500 [38:59<28:27,  8.41s/ticker]Success: AMPH | Credits: 298/800
# Downloading OHLCV:  60%|██████████▋       | 298/500 [39:04<24:57,  7.41s/ticker]Success: AMPL | Credits: 299/800
# Downloading OHLCV:  60%|██████████▊       | 299/500 [39:15<28:23,  8.47s/ticker]Success: AMPX | Credits: 300/800
# Downloading OHLCV:  60%|██████████▊       | 300/500 [39:20<24:30,  7.35s/ticker]Success: AMPY | Credits: 301/800
# Downloading OHLCV:  60%|██████████▊       | 301/500 [39:30<27:48,  8.39s/ticker]Success: AMR | Credits: 302/800
# Downloading OHLCV:  60%|██████████▊       | 302/500 [39:35<24:16,  7.36s/ticker]Success: AMRC | Credits: 303/800
# Downloading OHLCV:  61%|██████████▉       | 303/500 [39:46<27:30,  8.38s/ticker]Success: AMRK | Credits: 304/800
# Downloading OHLCV:  61%|██████████▉       | 304/500 [39:51<24:01,  7.36s/ticker]Success: AMRN | Credits: 305/800
# Downloading OHLCV:  61%|██████████▉       | 305/500 [40:02<27:33,  8.48s/ticker]Success: AMRX | Credits: 306/800
# Downloading OHLCV:  61%|███████████       | 306/500 [40:07<23:41,  7.33s/ticker]Success: AMSC | Credits: 307/800
# Downloading OHLCV:  61%|███████████       | 307/500 [40:18<27:09,  8.44s/ticker]Success: AMSF | Credits: 308/800
# Downloading OHLCV:  62%|███████████       | 308/500 [40:22<23:13,  7.26s/ticker]Success: AMST | Credits: 309/800
# Downloading OHLCV:  62%|███████████       | 309/500 [40:34<26:54,  8.45s/ticker]Success: AMT | Credits: 310/800
# Downloading OHLCV:  62%|███████████▏      | 310/500 [40:38<23:00,  7.27s/ticker]Success: AMTB | Credits: 311/800
# Downloading OHLCV:  62%|███████████▏      | 311/500 [40:49<26:36,  8.45s/ticker]Success: AMTD | Credits: 312/800
# Downloading OHLCV:  62%|███████████▏      | 312/500 [40:54<22:33,  7.20s/ticker]Success: AMTM | Credits: 313/800
# Downloading OHLCV:  63%|███████████▎      | 313/500 [41:05<26:33,  8.52s/ticker]Success: AMTX | Credits: 314/800
# Downloading OHLCV:  63%|███████████▎      | 314/500 [41:09<22:20,  7.21s/ticker]Success: AMWD | Credits: 315/800
# Downloading OHLCV:  63%|███████████▎      | 315/500 [41:21<26:39,  8.65s/ticker]Success: AMWL | Credits: 316/800
# Downloading OHLCV:  63%|███████████▍      | 316/500 [41:25<21:57,  7.16s/ticker]Success: AMX | Credits: 317/800
# Downloading OHLCV:  63%|███████████▍      | 317/500 [41:38<26:39,  8.74s/ticker]Success: AMZN | Credits: 318/800
# Downloading OHLCV:  64%|███████████▍      | 318/500 [41:41<21:36,  7.12s/ticker]Success: AN | Credits: 319/800
# Downloading OHLCV:  64%|███████████▍      | 319/500 [41:53<26:03,  8.64s/ticker]Success: ANAB | Credits: 320/800
# Downloading OHLCV:  64%|███████████▌      | 320/500 [41:57<21:13,  7.08s/ticker]Success: ANDE | Credits: 321/800
# Downloading OHLCV:  64%|███████████▌      | 321/500 [42:09<25:49,  8.65s/ticker]Success: ANEB | Credits: 322/800
# Downloading OHLCV:  64%|███████████▌      | 322/500 [42:13<21:51,  7.37s/ticker]Success: ANET | Credits: 323/800
# Downloading OHLCV:  65%|███████████▋      | 323/500 [42:24<25:11,  8.54s/ticker]Success: ANF | Credits: 324/800
# Downloading OHLCV:  65%|███████████▋      | 324/500 [42:29<21:16,  7.25s/ticker]No data for ANG: No data is available on the specified dates. Try setting different start/end dates.
# Failed: ANG
# Downloading OHLCV:  65%|███████████▋      | 325/500 [42:41<25:06,  8.61s/ticker]Success: ANGH | Credits: 326/800
# Downloading OHLCV:  65%|███████████▋      | 326/500 [42:44<20:54,  7.21s/ticker]Success: ANGHW | Credits: 327/800
# Downloading OHLCV:  65%|███████████▊      | 327/500 [42:57<25:10,  8.73s/ticker]Success: ANGI | Credits: 328/800
# Downloading OHLCV:  66%|███████████▊      | 328/500 [43:00<20:29,  7.15s/ticker]Success: ANGO | Credits: 329/800
# Downloading OHLCV:  66%|███████████▊      | 329/500 [43:12<24:46,  8.69s/ticker]Success: ANIK | Credits: 330/800
# Downloading OHLCV:  66%|███████████▉      | 330/500 [43:16<20:26,  7.22s/ticker]Success: ANIP | Credits: 331/800
# Downloading OHLCV:  66%|███████████▉      | 331/500 [43:28<24:08,  8.57s/ticker]Success: ANIX | Credits: 332/800
# Downloading OHLCV:  66%|███████████▉      | 332/500 [43:32<20:09,  7.20s/ticker]Success: ANL | Credits: 333/800
# Downloading OHLCV:  67%|███████████▉      | 333/500 [43:44<23:40,  8.51s/ticker]Success: ANNA | Credits: 334/800
# Downloading OHLCV:  67%|████████████      | 334/500 [43:48<20:02,  7.24s/ticker]Success: ANNAW | Credits: 335/800
# Downloading OHLCV:  67%|████████████      | 335/500 [43:59<23:30,  8.55s/ticker]Success: ANNX | Credits: 336/800
# Downloading OHLCV:  67%|████████████      | 336/500 [44:04<20:00,  7.32s/ticker]Success: ANRO | Credits: 337/800
# Downloading OHLCV:  67%|████████████▏     | 337/500 [44:15<22:56,  8.45s/ticker]Success: ANSC | Credits: 338/800
# Downloading OHLCV:  68%|████████████▏     | 338/500 [44:20<19:55,  7.38s/ticker]Success: ANSCW | Credits: 339/800
# Downloading OHLCV:  68%|████████████▏     | 339/500 [44:31<22:43,  8.47s/ticker]Success: ANSS | Credits: 340/800
# Downloading OHLCV:  68%|████████████▏     | 340/500 [44:36<19:35,  7.35s/ticker]Success: ANTE | Credits: 341/800
# Downloading OHLCV:  68%|████████████▎     | 341/500 [44:46<22:13,  8.38s/ticker]Success: ANTX | Credits: 342/800
# Downloading OHLCV:  68%|████████████▎     | 342/500 [44:52<19:35,  7.44s/ticker]Success: ANVS | Credits: 343/800
# Downloading OHLCV:  69%|████████████▎     | 343/500 [45:02<22:08,  8.46s/ticker]Success: ANY | Credits: 344/800
# Downloading OHLCV:  69%|████████████▍     | 344/500 [45:07<19:12,  7.39s/ticker]Success: AOD | Credits: 345/800
# Downloading OHLCV:  69%|████████████▍     | 345/500 [45:18<21:46,  8.43s/ticker]Success: AOMN | Credits: 346/800
# Downloading OHLCV:  69%|████████████▍     | 346/500 [45:23<19:02,  7.42s/ticker]Success: AOMR | Credits: 347/800
# Downloading OHLCV:  69%|████████████▍     | 347/500 [45:34<21:41,  8.51s/ticker]Success: AON | Credits: 348/800
# Downloading OHLCV:  70%|████████████▌     | 348/500 [45:39<18:28,  7.29s/ticker]Success: AORT | Credits: 349/800
# Downloading OHLCV:  70%|████████████▌     | 349/500 [45:51<21:44,  8.64s/ticker]Success: AOS | Credits: 350/800
# Downloading OHLCV:  70%|████████████▌     | 350/500 [45:55<18:05,  7.24s/ticker]Success: AOSL | Credits: 351/800
# Downloading OHLCV:  70%|████████████▋     | 351/500 [46:06<21:20,  8.60s/ticker]Success: AOUT | Credits: 352/800
# Downloading OHLCV:  70%|████████████▋     | 352/500 [46:10<17:45,  7.20s/ticker]Success: AP | Credits: 353/800
# Downloading OHLCV:  71%|████████████▋     | 353/500 [46:22<20:53,  8.52s/ticker]Success: APA | Credits: 354/800
# Downloading OHLCV:  71%|████████████▋     | 354/500 [46:26<17:48,  7.32s/ticker]Success: APAM | Credits: 355/800
# Downloading OHLCV:  71%|████████████▊     | 355/500 [46:38<20:31,  8.49s/ticker]Success: APCX | Credits: 356/800
# Downloading OHLCV:  71%|████████████▊     | 356/500 [46:42<17:30,  7.30s/ticker]Success: APD | Credits: 357/800
# Downloading OHLCV:  71%|████████████▊     | 357/500 [46:53<20:06,  8.44s/ticker]Success: APDN | Credits: 358/800
# Downloading OHLCV:  72%|████████████▉     | 358/500 [46:58<17:30,  7.40s/ticker]Success: APEI | Credits: 359/800
# Downloading OHLCV:  72%|████████████▉     | 359/500 [47:09<19:41,  8.38s/ticker]Success: APG | Credits: 360/800
# Downloading OHLCV:  72%|████████████▉     | 360/500 [47:14<17:09,  7.35s/ticker]Success: APGE | Credits: 361/800
# Downloading OHLCV:  72%|████████████▉     | 361/500 [47:24<19:15,  8.31s/ticker]Success: APH | Credits: 362/800
# Downloading OHLCV:  72%|█████████████     | 362/500 [47:30<17:11,  7.47s/ticker]Success: API | Credits: 363/800
# Downloading OHLCV:  73%|█████████████     | 363/500 [47:40<18:51,  8.26s/ticker]Success: APLD | Credits: 364/800
# Downloading OHLCV:  73%|█████████████     | 364/500 [47:45<16:47,  7.41s/ticker]Success: APLE | Credits: 365/800
# Downloading OHLCV:  73%|█████████████▏    | 365/500 [47:55<18:28,  8.21s/ticker]Success: APLM | Credits: 366/800
# Downloading OHLCV:  73%|█████████████▏    | 366/500 [48:01<16:27,  7.37s/ticker]Success: APLMW | Credits: 367/800
# Downloading OHLCV:  73%|█████████████▏    | 367/500 [48:12<18:44,  8.45s/ticker]Success: APLS | Credits: 368/800
# Downloading OHLCV:  74%|█████████████▏    | 368/500 [48:16<16:03,  7.30s/ticker]Success: APLT | Credits: 369/800
# Downloading OHLCV:  74%|█████████████▎    | 369/500 [48:28<18:26,  8.45s/ticker]Success: APM | Credits: 370/800
# Downloading OHLCV:  74%|█████████████▎    | 370/500 [48:34<16:54,  7.80s/ticker]Success: APO | Credits: 371/800
# Downloading OHLCV:  74%|█████████████▎    | 371/500 [48:43<17:49,  8.29s/ticker]Success: APOG | Credits: 372/800
# Downloading OHLCV:  74%|█████████████▍    | 372/500 [48:50<16:25,  7.70s/ticker]Success: APOS | Credits: 373/800
# Downloading OHLCV:  75%|█████████████▍    | 373/500 [49:00<17:45,  8.39s/ticker]Success: APP | Credits: 374/800
# Downloading OHLCV:  75%|█████████████▍    | 374/500 [49:05<15:48,  7.52s/ticker]Success: APPF | Credits: 375/800
# Downloading OHLCV:  75%|█████████████▌    | 375/500 [49:16<17:35,  8.45s/ticker]Success: APPN | Credits: 376/800
# Downloading OHLCV:  75%|█████████████▌    | 376/500 [49:21<15:16,  7.39s/ticker]Success: APPS | Credits: 377/800
# Downloading OHLCV:  75%|█████████████▌    | 377/500 [49:31<17:07,  8.35s/ticker]Success: APRE | Credits: 378/800
# Downloading OHLCV:  76%|█████████████▌    | 378/500 [49:36<14:53,  7.32s/ticker]Success: APTV | Credits: 379/800
# Downloading OHLCV:  76%|█████████████▋    | 379/500 [49:47<16:52,  8.37s/ticker]Success: APVO | Credits: 380/800
# Downloading OHLCV:  76%|█████████████▋    | 380/500 [49:52<14:52,  7.44s/ticker]Success: APWC | Credits: 381/800
# Downloading OHLCV:  76%|█████████████▋    | 381/500 [50:03<16:55,  8.54s/ticker]Success: APYX | Credits: 382/800
# Downloading OHLCV:  76%|█████████████▊    | 382/500 [50:08<14:33,  7.40s/ticker]Success: AQB | Credits: 383/800
# Downloading OHLCV:  77%|█████████████▊    | 383/500 [50:19<16:36,  8.52s/ticker]Success: AQMS | Credits: 384/800
# Downloading OHLCV:  77%|█████████████▊    | 384/500 [50:24<14:26,  7.47s/ticker]Success: AQN | Credits: 385/800
# Downloading OHLCV:  77%|█████████████▊    | 385/500 [50:35<16:09,  8.43s/ticker]Success: AQNB | Credits: 386/800
# Downloading OHLCV:  77%|█████████████▉    | 386/500 [50:40<14:17,  7.52s/ticker]Success: AQST | Credits: 387/800
# Downloading OHLCV:  77%|█████████████▉    | 387/500 [50:51<15:57,  8.48s/ticker]Success: AR | Credits: 388/800
# Downloading OHLCV:  78%|█████████████▉    | 388/500 [50:56<13:46,  7.38s/ticker]Success: ARAY | Credits: 389/800
# Downloading OHLCV:  78%|██████████████    | 389/500 [51:07<15:36,  8.44s/ticker]Success: ARBB | Credits: 390/800
# Downloading OHLCV:  78%|██████████████    | 390/500 [51:12<13:38,  7.44s/ticker]Success: ARBE | Credits: 391/800
# Downloading OHLCV:  78%|██████████████    | 391/500 [51:23<15:17,  8.42s/ticker]Success: ARBEW | Credits: 392/800
# Downloading OHLCV:  78%|██████████████    | 392/500 [51:28<13:32,  7.52s/ticker]Success: ARBK | Credits: 393/800
# Downloading OHLCV:  79%|██████████████▏   | 393/500 [51:38<14:54,  8.36s/ticker]Success: ARBKL | Credits: 394/800
# Downloading OHLCV:  79%|██████████████▏   | 394/500 [51:44<13:32,  7.66s/ticker]Success: ARCB | Credits: 395/800
# Downloading OHLCV:  79%|██████████████▏   | 395/500 [51:54<14:31,  8.30s/ticker]Success: ARCC | Credits: 396/800
# Downloading OHLCV:  79%|██████████████▎   | 396/500 [52:00<13:10,  7.60s/ticker]Success: ARCO | Credits: 397/800
# Downloading OHLCV:  79%|██████████████▎   | 397/500 [52:10<14:05,  8.21s/ticker]Success: ARCT | Credits: 398/800
# Downloading OHLCV:  80%|██████████████▎   | 398/500 [52:16<12:53,  7.58s/ticker]Success: ARDC | Credits: 399/800
# Downloading OHLCV:  80%|██████████████▎   | 399/500 [52:25<13:41,  8.14s/ticker]Success: ARDT | Credits: 400/800
# Downloading OHLCV:  80%|██████████████▍   | 400/500 [52:31<12:32,  7.52s/ticker]Success: ARDX | Credits: 401/800
# Downloading OHLCV:  80%|██████████████▍   | 401/500 [52:41<13:21,  8.10s/ticker]Success: ARE | Credits: 402/800
# Downloading OHLCV:  80%|██████████████▍   | 402/500 [52:47<12:20,  7.56s/ticker]Success: AREB | Credits: 403/800
# Downloading OHLCV:  81%|██████████████▌   | 403/500 [52:56<13:01,  8.05s/ticker]Success: AREBW | Credits: 404/800
# Downloading OHLCV:  81%|██████████████▌   | 404/500 [53:03<12:14,  7.65s/ticker]Success: AREC | Credits: 405/800
# Downloading OHLCV:  81%|██████████████▌   | 405/500 [53:12<12:52,  8.13s/ticker]Success: ARES | Credits: 406/800
# Downloading OHLCV:  81%|██████████████▌   | 406/500 [53:19<12:09,  7.76s/ticker]Success: ARGD | Credits: 407/800
# Downloading OHLCV:  81%|██████████████▋   | 407/500 [53:28<12:39,  8.16s/ticker]No data for ARGO: **symbol** ARGO is not available with your plan. You may select the appropriate plan at https://twelvedata.com/pricing
# Failed: ARGO
# Downloading OHLCV:  82%|██████████████▋   | 408/500 [53:35<11:48,  7.70s/ticker]Success: ARGX | Credits: 409/800
# Downloading OHLCV:  82%|██████████████▋   | 409/500 [53:44<12:14,  8.07s/ticker]Success: ARHS | Credits: 410/800
# Downloading OHLCV:  82%|██████████████▊   | 410/500 [53:51<11:31,  7.69s/ticker]Success: ARI | Credits: 411/800
# Downloading OHLCV:  82%|██████████████▊   | 411/500 [53:59<11:51,  7.99s/ticker]Success: ARIS | Credits: 412/800
# Downloading OHLCV:  82%|██████████████▊   | 412/500 [54:06<11:16,  7.69s/ticker]Success: ARKO | Credits: 413/800
# Downloading OHLCV:  83%|██████████████▊   | 413/500 [54:15<11:32,  7.96s/ticker]Success: ARKOW | Credits: 414/800
# Downloading OHLCV:  83%|██████████████▉   | 414/500 [54:22<11:08,  7.77s/ticker]Success: ARKR | Credits: 415/800
# Downloading OHLCV:  83%|██████████████▉   | 415/500 [54:32<11:43,  8.27s/ticker]Success: ARL | Credits: 416/800
# Downloading OHLCV:  83%|██████████████▉   | 416/500 [54:38<10:55,  7.80s/ticker]Success: ARLO | Credits: 417/800
# Downloading OHLCV:  83%|███████████████   | 417/500 [54:47<11:17,  8.17s/ticker]Success: ARLP | Credits: 418/800
# Downloading OHLCV:  84%|███████████████   | 418/500 [54:54<10:33,  7.72s/ticker]Success: ARM | Credits: 419/800
# Downloading OHLCV:  84%|███████████████   | 419/500 [55:03<11:04,  8.21s/ticker]Success: ARMK | Credits: 420/800
# Downloading OHLCV:  84%|███████████████   | 420/500 [55:10<10:13,  7.67s/ticker]Success: AROC | Credits: 421/800
# Downloading OHLCV:  84%|███████████████▏  | 421/500 [55:19<10:53,  8.27s/ticker]Success: AROW | Credits: 422/800
# Downloading OHLCV:  84%|███████████████▏  | 422/500 [55:26<09:52,  7.60s/ticker]Success: ARQ | Credits: 423/800
# Downloading OHLCV:  85%|███████████████▏  | 423/500 [55:35<10:34,  8.24s/ticker]Success: ARQQ | Credits: 424/800
# Downloading OHLCV:  85%|███████████████▎  | 424/500 [55:41<09:35,  7.57s/ticker]Success: ARQQW | Credits: 425/800
# Downloading OHLCV:  85%|███████████████▎  | 425/500 [55:51<10:10,  8.14s/ticker]Success: ARQT | Credits: 426/800
# Downloading OHLCV:  85%|███████████████▎  | 426/500 [55:57<09:25,  7.64s/ticker]Success: ARR | Credits: 427/800
# Downloading OHLCV:  85%|███████████████▎  | 427/500 [56:06<09:48,  8.06s/ticker]Success: ARRY | Credits: 428/800
# Downloading OHLCV:  86%|███████████████▍  | 428/500 [56:13<09:06,  7.58s/ticker]Success: ARTL | Credits: 429/800
# Downloading OHLCV:  86%|███████████████▍  | 429/500 [56:22<09:42,  8.20s/ticker]Success: ARTNA | Credits: 430/800
# Downloading OHLCV:  86%|███████████████▍  | 430/500 [56:29<08:57,  7.68s/ticker]Success: ARTV | Credits: 431/800
# Downloading OHLCV:  86%|███████████████▌  | 431/500 [56:38<09:25,  8.20s/ticker]Success: ARTW | Credits: 432/800
# Downloading OHLCV:  86%|███████████████▌  | 432/500 [56:45<08:39,  7.64s/ticker]Success: ARVN | Credits: 433/800
# Downloading OHLCV:  87%|███████████████▌  | 433/500 [56:54<09:08,  8.18s/ticker]Success: ARW | Credits: 434/800
# Downloading OHLCV:  87%|███████████████▌  | 434/500 [57:00<08:22,  7.62s/ticker]Success: ARWR | Credits: 435/800
# Downloading OHLCV:  87%|███████████████▋  | 435/500 [57:10<08:51,  8.18s/ticker]Success: AS | Credits: 436/800
# Downloading OHLCV:  87%|███████████████▋  | 436/500 [57:22<09:51,  9.25s/ticker]Success: ASA | Credits: 437/800
# Downloading OHLCV:  87%|███████████████▋  | 437/500 [57:26<08:03,  7.68s/ticker]Success: ASAN | Credits: 438/800
# Downloading OHLCV:  88%|███████████████▊  | 438/500 [57:38<09:18,  9.00s/ticker]Success: ASB | Credits: 439/800
# Downloading OHLCV:  88%|███████████████▊  | 439/500 [57:41<07:28,  7.35s/ticker]Success: ASBA | Credits: 440/800
# Downloading OHLCV:  88%|███████████████▊  | 440/500 [57:54<08:58,  8.97s/ticker]Success: ASBP | Credits: 441/800
# Downloading OHLCV:  88%|███████████████▉  | 441/500 [57:57<06:58,  7.10s/ticker]Success: ASBPW | Credits: 442/800
# Downloading OHLCV:  88%|███████████████▉  | 442/500 [58:10<08:36,  8.91s/ticker]Success: ASC | Credits: 443/800
# Downloading OHLCV:  89%|███████████████▉  | 443/500 [58:12<06:39,  7.02s/ticker]Success: ASG | Credits: 444/800
# Downloading OHLCV:  89%|███████████████▉  | 444/500 [58:26<08:23,  9.00s/ticker]Success: ASGI | Credits: 445/800
# Downloading OHLCV:  89%|████████████████  | 445/500 [58:28<06:26,  7.04s/ticker]Success: ASGN | Credits: 446/800
# Downloading OHLCV:  89%|████████████████  | 446/500 [58:42<08:06,  9.01s/ticker]Success: ASH | Credits: 447/800
# Downloading OHLCV:  89%|████████████████  | 447/500 [58:44<06:04,  6.88s/ticker]Success: ASIX | Credits: 448/800
# Downloading OHLCV:  90%|████████████████▏ | 448/500 [58:58<07:42,  8.90s/ticker]Success: ASLE | Credits: 449/800
# Downloading OHLCV:  90%|████████████████▏ | 449/500 [58:59<05:46,  6.79s/ticker]Success: ASMB | Credits: 450/800
# Downloading OHLCV:  90%|████████████████▏ | 450/500 [59:13<07:24,  8.90s/ticker]Success: ASML | Credits: 451/800
# Downloading OHLCV:  90%|████████████████▏ | 451/500 [59:15<05:30,  6.75s/ticker]Success: ASND | Credits: 452/800
# Downloading OHLCV:  90%|████████████████▎ | 452/500 [59:29<07:13,  9.03s/ticker]Success: ASNS | Credits: 453/800
# Downloading OHLCV:  91%|████████████████▎ | 453/500 [59:31<05:22,  6.85s/ticker]Success: ASO | Credits: 454/800
# Downloading OHLCV:  91%|████████████████▎ | 454/500 [59:45<06:50,  8.92s/ticker]Success: ASPC | Credits: 455/800
# Downloading OHLCV:  91%|████████████████▍ | 455/500 [59:47<05:04,  6.76s/ticker]Success: ASPI | Credits: 456/800
# Downloading OHLCV:  91%|██████████████▌ | 456/500 [1:00:00<06:29,  8.86s/ticker]Success: ASPN | Credits: 457/800
# Downloading OHLCV:  91%|██████████████▌ | 457/500 [1:00:02<04:49,  6.73s/ticker]Success: ASPS | Credits: 458/800
# Downloading OHLCV:  92%|██████████████▋ | 458/500 [1:00:16<06:13,  8.90s/ticker]Success: ASPSW | Credits: 459/800
# Downloading OHLCV:  92%|██████████████▋ | 459/500 [1:00:18<04:39,  6.82s/ticker]Success: ASPSZ | Credits: 460/800
# Downloading OHLCV:  92%|██████████████▋ | 460/500 [1:00:32<05:58,  8.97s/ticker]Success: ASR | Credits: 461/800
# Downloading OHLCV:  92%|██████████████▊ | 461/500 [1:00:34<04:25,  6.81s/ticker]Success: ASRT | Credits: 462/800
# Downloading OHLCV:  92%|██████████████▊ | 462/500 [1:00:48<05:37,  8.89s/ticker]Success: ASRV | Credits: 463/800
# Downloading OHLCV:  93%|██████████████▊ | 463/500 [1:00:49<04:10,  6.76s/ticker]Success: ASST | Credits: 464/800
# Downloading OHLCV:  93%|██████████████▊ | 464/500 [1:01:03<05:20,  8.90s/ticker]Success: ASTC | Credits: 465/800
# Downloading OHLCV:  93%|██████████████▉ | 465/500 [1:01:05<03:56,  6.76s/ticker]Success: ASTE | Credits: 466/800
# Downloading OHLCV:  93%|██████████████▉ | 466/500 [1:01:19<05:06,  9.03s/ticker]Success: ASTH | Credits: 467/800
# Downloading OHLCV:  93%|██████████████▉ | 467/500 [1:01:21<03:46,  6.87s/ticker]Success: ASTI | Credits: 468/800
# Downloading OHLCV:  94%|██████████████▉ | 468/500 [1:01:35<04:46,  8.96s/ticker]Success: ASTL | Credits: 469/800
# Downloading OHLCV:  94%|███████████████ | 469/500 [1:01:37<03:31,  6.83s/ticker]Success: ASTLW | Credits: 470/800
# Downloading OHLCV:  94%|███████████████ | 470/500 [1:01:51<04:32,  9.09s/ticker]Success: ASTS | Credits: 471/800
# Downloading OHLCV:  94%|███████████████ | 471/500 [1:01:53<03:16,  6.77s/ticker]Success: ASUR | Credits: 472/800
# Downloading OHLCV:  94%|███████████████ | 472/500 [1:02:07<04:11,  8.99s/ticker]Success: ASX | Credits: 473/800
# Downloading OHLCV:  95%|███████████████▏| 473/500 [1:02:09<03:06,  6.90s/ticker]Success: ASYS | Credits: 474/800
# Downloading OHLCV:  95%|███████████████▏| 474/500 [1:02:23<03:57,  9.14s/ticker]Success: ATAI | Credits: 475/800
# Downloading OHLCV:  95%|███████████████▏| 475/500 [1:02:24<02:50,  6.81s/ticker]Success: ATAT | Credits: 476/800
# Downloading OHLCV:  95%|███████████████▏| 476/500 [1:02:39<03:37,  9.07s/ticker]No data for ATCO: **symbol** or **figi** parameter is missing or invalid. Please provide a valid symbol according to API documentation: https://twelvedata.com/docs#reference-data
# Failed: ATCO
# Downloading OHLCV:  95%|███████████████▎| 477/500 [1:02:40<02:33,  6.70s/ticker]Success: ATCOL | Credits: 478/800
# Downloading OHLCV:  96%|███████████████▎| 478/500 [1:02:55<03:22,  9.22s/ticker]Success: ATEC | Credits: 479/800
# Downloading OHLCV:  96%|███████████████▎| 479/500 [1:02:56<02:18,  6.60s/ticker]Success: ATEN | Credits: 480/800
# Downloading OHLCV:  96%|███████████████▎| 480/500 [1:03:11<03:02,  9.13s/ticker]Success: ATER | Credits: 481/800
# Downloading OHLCV:  96%|███████████████▍| 481/500 [1:03:11<02:05,  6.61s/ticker]Success: ATEX | Credits: 482/800
# Downloading OHLCV:  96%|███████████████▍| 482/500 [1:03:26<02:43,  9.09s/ticker]Success: ATGE | Credits: 483/800
# Downloading OHLCV:  97%|███████████████▍| 483/500 [1:03:27<01:54,  6.73s/ticker]Success: ATGL | Credits: 484/800
# Downloading OHLCV:  97%|███████████████▍| 484/500 [1:03:42<02:24,  9.02s/ticker]No data for ATH: **symbol** ATH is not available with your plan. You may select the appropriate plan at https://twelvedata.com/pricing
# Failed: ATH
# Downloading OHLCV:  97%|███████████████▌| 485/500 [1:03:43<01:41,  6.75s/ticker]Success: ATHA | Credits: 486/800
# Downloading OHLCV:  97%|███████████████▌| 486/500 [1:03:57<02:05,  8.94s/ticker]Success: ATHE | Credits: 487/800
# Downloading OHLCV:  97%|███████████████▌| 487/500 [1:03:59<01:27,  6.70s/ticker]Success: ATHM | Credits: 488/800
# Downloading OHLCV:  98%|███████████████▌| 488/500 [1:04:13<01:48,  9.08s/ticker]Success: ATHR | Credits: 489/800
# Downloading OHLCV:  98%|███████████████▋| 489/500 [1:04:15<01:14,  6.73s/ticker]Success: ATHS | Credits: 490/800
# Downloading OHLCV:  98%|███████████████▋| 490/500 [1:04:29<01:31,  9.14s/ticker]Success: ATI | Credits: 491/800
# Downloading OHLCV:  98%|███████████████▋| 491/500 [1:04:30<01:00,  6.70s/ticker]Success: ATII | Credits: 492/800
# Downloading OHLCV:  98%|███████████████▋| 492/500 [1:04:45<01:13,  9.18s/ticker]Success: ATIIU | Credits: 493/800
# Downloading OHLCV:  99%|███████████████▊| 493/500 [1:04:46<00:46,  6.71s/ticker]Success: ATKR | Credits: 494/800
# Downloading OHLCV:  99%|███████████████▊| 494/500 [1:05:01<00:54,  9.13s/ticker]Success: ATLC | Credits: 495/800
# Downloading OHLCV:  99%|███████████████▊| 495/500 [1:05:02<00:33,  6.62s/ticker]Success: ATLCL | Credits: 496/800
# Downloading OHLCV:  99%|███████████████▊| 496/500 [1:05:17<00:37,  9.26s/ticker]Success: ATLCP | Credits: 497/800
# Downloading OHLCV:  99%|███████████████▉| 497/500 [1:05:18<00:20,  6.81s/ticker]Success: ATLCZ | Credits: 498/800
# Downloading OHLCV: 100%|███████████████▉| 498/500 [1:05:33<00:18,  9.22s/ticker]Success: ATLN | Credits: 499/800
# Downloading OHLCV: 100%|███████████████▉| 499/500 [1:05:35<00:07,  7.05s/ticker]Success: ATLO | Credits: 500/800
# Downloading OHLCV: 100%|████████████████| 500/500 [1:05:49<00:00,  7.90s/ticker]
# Saved 359244 records | Failed: 5
# Saved 888 macro records
#
# === Pipeline Report ===
# OHLCV Records: 359244
# Macro Data Points: 888
# API Credits Used: 500/800
# Data saved to: /Users/abduljalaalabubakar/Desktop/Projects/ML Projects/Axya/data
